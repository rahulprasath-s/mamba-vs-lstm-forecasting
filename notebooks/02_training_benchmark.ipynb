# %% [markdown]
# # Training Benchmark
#
# Run the benchmark script and inspect saved metrics.

# %%
# !python ../main.py --epochs 5 --output-dir ../results

# %%
from pathlib import Path

import pandas as pd

results_dir = Path('../results')
pd.read_csv(results_dir / 'benchmark_metrics.csv')

# %%
from IPython.display import Image, display

display(Image(filename=results_dir / 'loss_curve.png'))
display(Image(filename=results_dir / 'speed_bar.png'))
